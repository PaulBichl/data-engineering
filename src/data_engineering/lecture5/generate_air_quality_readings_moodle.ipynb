# %%
import os
import random
import time
from datetime import datetime
import xml.etree.ElementTree as ET
from xml.dom import minidom
import pandas as pd
from sklearn.linear_model import LinearRegression

# Create output directory
output_dir = "sensor_data/xml"
os.makedirs(output_dir, exist_ok=True)

def classify_health_environment(pm2_5, pm10, so2, no2):
    score = 0
    if pm2_5 > 100: score += 1
    if pm10 > 150: score += 1
    if so2 > 100: score += 1
    if no2 is not None and no2 > 200: score += 1

    if score == 0:
        return "Good"
    elif score == 1:
        return "Moderate"
    else:
        return "Unhealthy"
    
# Function to generate random air quality data
def generate_air_quality_data(sensor_id=3):
    pm2_5 = round(random.uniform(0, 250), 2)
    pm10 = round(random.uniform(0, 500), 2)
    so2 = round(random.uniform(0, 300), 2)
    no2 = round(random.uniform(0, 500), 2) if random.random() > 0.2 else None

    health_environment = classify_health_environment(pm2_5, pm10, so2, no2)

    return {
        "sensor_id": sensor_id,
        "timestamp": datetime.now().isoformat(),
        "pm2_5": pm2_5,
        "pm10": pm10,
        "so2": so2,
        "no2": no2,
        "health_environment": health_environment.lower()
    }

# Impute only no2 values using mean, median, mode or regression
def impute_missing_values(df, strategy='mean'):
    if strategy == 'mean':
        df['no2'] = df['no2'].fillna(df['no2'].mean()).round(2)
    elif strategy == 'median':
         df['no2'] = df['no2'].fillna(df['no2'].median()).round(2)
    elif strategy == 'mode':
        df['no2'] = df['no2'].fillna(df['no2'].mode()).round(2)
    elif strategy == 'regression':
        # Only impute no2 values using so2 as predictor
        hum_train = df.dropna(subset=['no2'])
        model = LinearRegression()
        model.fit(hum_train[['so2']], hum_train['no2'])
        hum_missing = df[df['no2'].isnull()]
        df.loc[df['no2'].isnull(), 'no2'] = model.predict(hum_missing[['so2']]).round(2)
    return df

# Function to save data as XML
def save_air_quality_xml(filename, data):
    root = ET.Element("AirQualityReadings")
    for reading in data:
        reading_elem = ET.SubElement(root, "Reading")
        for key, value in reading.items():
            elem = ET.SubElement(reading_elem, key)
            elem.text = str(value)
    # Convert to string and pretty-print
    rough_string = ET.tostring(root, 'utf-8')
    reparsed = minidom.parseString(rough_string)
    pretty_xml = reparsed.toprettyxml(indent="  ")

    # Save to file
    filepath = os.path.join(output_dir, filename)
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(pretty_xml)

    print(f"Saved Air Quality XML: {filepath}")

# User input for number of times to run
num_iterations = int(input("Enter number of air quality readings to generate: "))

# Generate multiple batches of air quality data
readings = []
for i in range(num_iterations):
    air_quality_data = generate_air_quality_data()
    print(air_quality_data)
    readings.append(air_quality_data)
    time.sleep(0.01)  # Simulate real-time data generation

    # Add a duplicate at every 3rd reading
    if i % 3 == 0 and i != 0:
        readings.append(air_quality_data)
        print(air_quality_data)

# Create DataFrame
df = pd.DataFrame(readings)

# Save raw data (with duplicates)
save_air_quality_xml("air_quality_readings_errors.xml", df.to_dict(orient='records'))

# Remove duplicated rows
df = df.drop_duplicates()

# Impute missing no2 values 
df = impute_missing_values(df, strategy="mean")

# Save cleaned data (without duplicates)
save_air_quality_xml("air_quality_readings.xml", df.to_dict(orient='records'))

df.to_csv("sensor_data/air_quality_reading.csv", index=False)
# Out:
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:17.982871', 'pm2_5': 128.86, 'pm10': 37.31, 'so2': 154.91, 'no2': 205.22, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:17.994871', 'pm2_5': 101.64, 'pm10': 436.73, 'so2': 100.36, 'no2': 230.7, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.005873', 'pm2_5': 159.42, 'pm10': 30.48, 'so2': 102.48, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.016885', 'pm2_5': 28.07, 'pm10': 101.36, 'so2': 258.9, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.016885', 'pm2_5': 28.07, 'pm10': 101.36, 'so2': 258.9, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.027885', 'pm2_5': 209.25, 'pm10': 436.96, 'so2': 248.1, 'no2': 400.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.038886', 'pm2_5': 237.87, 'pm10': 130.8, 'so2': 186.4, 'no2': 287.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.049894', 'pm2_5': 248.88, 'pm10': 168.54, 'so2': 207.44, 'no2': 132.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.049894', 'pm2_5': 248.88, 'pm10': 168.54, 'so2': 207.44, 'no2': 132.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.060887', 'pm2_5': 106.47, 'pm10': 275.88, 'so2': 216.01, 'no2': 155.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.071881', 'pm2_5': 8.95, 'pm10': 113.28, 'so2': 213.01, 'no2': 286.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.082881', 'pm2_5': 55.81, 'pm10': 129.93, 'so2': 81.9, 'no2': 211.95, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.082881', 'pm2_5': 55.81, 'pm10': 129.93, 'so2': 81.9, 'no2': 211.95, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.093880', 'pm2_5': 246.33, 'pm10': 163.5, 'so2': 173.06, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.104891', 'pm2_5': 231.59, 'pm10': 301.97, 'so2': 129.59, 'no2': 163.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.115893', 'pm2_5': 74.88, 'pm10': 24.98, 'so2': 268.44, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.115893', 'pm2_5': 74.88, 'pm10': 24.98, 'so2': 268.44, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.126883', 'pm2_5': 80.95, 'pm10': 296.68, 'so2': 177.41, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.137895', 'pm2_5': 145.78, 'pm10': 216.92, 'so2': 117.35, 'no2': 106.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.148885', 'pm2_5': 133.88, 'pm10': 412.55, 'so2': 106.03, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.148885', 'pm2_5': 133.88, 'pm10': 412.55, 'so2': 106.03, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.159884', 'pm2_5': 121.98, 'pm10': 114.32, 'so2': 60.1, 'no2': 216.17, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.170896', 'pm2_5': 91.76, 'pm10': 312.31, 'so2': 49.18, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.181897', 'pm2_5': 143.75, 'pm10': 194.37, 'so2': 285.17, 'no2': 135.23, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.181897', 'pm2_5': 143.75, 'pm10': 194.37, 'so2': 285.17, 'no2': 135.23, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.192899', 'pm2_5': 152.13, 'pm10': 37.92, 'so2': 262.59, 'no2': 64.9, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.203887', 'pm2_5': 11.94, 'pm10': 453.45, 'so2': 144.69, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.214889', 'pm2_5': 146.92, 'pm10': 250.83, 'so2': 292.42, 'no2': 23.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.214889', 'pm2_5': 146.92, 'pm10': 250.83, 'so2': 292.42, 'no2': 23.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.225891', 'pm2_5': 67.08, 'pm10': 298.44, 'so2': 275.03, 'no2': 234.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.236891', 'pm2_5': 25.49, 'pm10': 373.97, 'so2': 82.14, 'no2': 286.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.247891', 'pm2_5': 189.61, 'pm10': 296.3, 'so2': 154.04, 'no2': 216.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.247891', 'pm2_5': 189.61, 'pm10': 296.3, 'so2': 154.04, 'no2': 216.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.258903', 'pm2_5': 146.61, 'pm10': 79.17, 'so2': 144.62, 'no2': 220.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.269901', 'pm2_5': 181.11, 'pm10': 57.89, 'so2': 143.38, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.280891', 'pm2_5': 220.89, 'pm10': 289.56, 'so2': 223.85, 'no2': 196.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.280891', 'pm2_5': 220.89, 'pm10': 289.56, 'so2': 223.85, 'no2': 196.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.291898', 'pm2_5': 185.82, 'pm10': 62.27, 'so2': 131.28, 'no2': 132.54, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.302904', 'pm2_5': 67.83, 'pm10': 370.92, 'so2': 98.06, 'no2': 191.61, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.313896', 'pm2_5': 212.54, 'pm10': 363.7, 'so2': 95.05, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.313896', 'pm2_5': 212.54, 'pm10': 363.7, 'so2': 95.05, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.324896', 'pm2_5': 224.2, 'pm10': 472.85, 'so2': 226.54, 'no2': 203.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.335895', 'pm2_5': 26.51, 'pm10': 323.95, 'so2': 291.88, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.346897', 'pm2_5': 93.34, 'pm10': 348.17, 'so2': 113.14, 'no2': 221.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.346897', 'pm2_5': 93.34, 'pm10': 348.17, 'so2': 113.14, 'no2': 221.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.357910', 'pm2_5': 93.47, 'pm10': 179.16, 'so2': 51.94, 'no2': 495.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.368908', 'pm2_5': 233.96, 'pm10': 32.62, 'so2': 88.49, 'no2': 121.2, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.379910', 'pm2_5': 205.46, 'pm10': 405.35, 'so2': 121.59, 'no2': 376.85, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.379910', 'pm2_5': 205.46, 'pm10': 405.35, 'so2': 121.59, 'no2': 376.85, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.390913', 'pm2_5': 129.63, 'pm10': 190.44, 'so2': 39.0, 'no2': 427.92, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.401911', 'pm2_5': 159.57, 'pm10': 459.92, 'so2': 225.41, 'no2': 27.06, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.412911', 'pm2_5': 142.8, 'pm10': 494.96, 'so2': 94.88, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.412911', 'pm2_5': 142.8, 'pm10': 494.96, 'so2': 94.88, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.423904', 'pm2_5': 45.01, 'pm10': 84.95, 'so2': 193.04, 'no2': 451.79, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.435905', 'pm2_5': 242.61, 'pm10': 482.35, 'so2': 229.32, 'no2': 486.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.446914', 'pm2_5': 63.18, 'pm10': 149.47, 'so2': 91.44, 'no2': 97.3, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.446914', 'pm2_5': 63.18, 'pm10': 149.47, 'so2': 91.44, 'no2': 97.3, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.457907', 'pm2_5': 215.67, 'pm10': 270.35, 'so2': 34.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.468915', 'pm2_5': 71.65, 'pm10': 471.54, 'so2': 195.12, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.479918', 'pm2_5': 128.13, 'pm10': 275.61, 'so2': 102.92, 'no2': 362.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.479918', 'pm2_5': 128.13, 'pm10': 275.61, 'so2': 102.92, 'no2': 362.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.490909', 'pm2_5': 91.51, 'pm10': 176.95, 'so2': 298.06, 'no2': 301.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.501919', 'pm2_5': 200.89, 'pm10': 196.08, 'so2': 20.78, 'no2': 472.5, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.512919', 'pm2_5': 238.31, 'pm10': 387.34, 'so2': 272.93, 'no2': 340.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.512919', 'pm2_5': 238.31, 'pm10': 387.34, 'so2': 272.93, 'no2': 340.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.523913', 'pm2_5': 107.08, 'pm10': 419.82, 'so2': 48.33, 'no2': 394.58, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.534913', 'pm2_5': 43.24, 'pm10': 486.55, 'so2': 198.07, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.545913', 'pm2_5': 16.87, 'pm10': 412.18, 'so2': 179.58, 'no2': 284.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.545913', 'pm2_5': 16.87, 'pm10': 412.18, 'so2': 179.58, 'no2': 284.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.556914', 'pm2_5': 203.01, 'pm10': 226.42, 'so2': 165.57, 'no2': 40.58, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.567922', 'pm2_5': 95.12, 'pm10': 353.95, 'so2': 15.04, 'no2': 273.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.578917', 'pm2_5': 160.05, 'pm10': 214.32, 'so2': 135.74, 'no2': 349.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.578917', 'pm2_5': 160.05, 'pm10': 214.32, 'so2': 135.74, 'no2': 349.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.589924', 'pm2_5': 5.96, 'pm10': 377.09, 'so2': 12.21, 'no2': 173.89, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.600925', 'pm2_5': 94.99, 'pm10': 442.62, 'so2': 278.4, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.611926', 'pm2_5': 120.91, 'pm10': 59.89, 'so2': 155.05, 'no2': 165.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.611926', 'pm2_5': 120.91, 'pm10': 59.89, 'so2': 155.05, 'no2': 165.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.622927', 'pm2_5': 163.21, 'pm10': 248.01, 'so2': 183.41, 'no2': 401.72, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.633927', 'pm2_5': 41.17, 'pm10': 481.09, 'so2': 278.7, 'no2': 158.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.644919', 'pm2_5': 32.69, 'pm10': 417.6, 'so2': 237.95, 'no2': 92.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.644919', 'pm2_5': 32.69, 'pm10': 417.6, 'so2': 237.95, 'no2': 92.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.655919', 'pm2_5': 147.08, 'pm10': 473.05, 'so2': 31.6, 'no2': 78.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.666930', 'pm2_5': 26.91, 'pm10': 311.85, 'so2': 2.35, 'no2': 428.78, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.677930', 'pm2_5': 22.17, 'pm10': 324.71, 'so2': 18.31, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.677930', 'pm2_5': 22.17, 'pm10': 324.71, 'so2': 18.31, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.688921', 'pm2_5': 5.01, 'pm10': 242.16, 'so2': 204.05, 'no2': 34.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.699932', 'pm2_5': 119.25, 'pm10': 442.55, 'so2': 149.98, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.710933', 'pm2_5': 98.4, 'pm10': 400.88, 'so2': 263.76, 'no2': 417.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.710933', 'pm2_5': 98.4, 'pm10': 400.88, 'so2': 263.76, 'no2': 417.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.721934', 'pm2_5': 213.85, 'pm10': 94.69, 'so2': 168.8, 'no2': 466.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.732935', 'pm2_5': 54.32, 'pm10': 487.23, 'so2': 31.44, 'no2': 239.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.743926', 'pm2_5': 53.72, 'pm10': 132.63, 'so2': 104.12, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.743926', 'pm2_5': 53.72, 'pm10': 132.63, 'so2': 104.12, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.754485', 'pm2_5': 102.3, 'pm10': 391.28, 'so2': 257.35, 'no2': 493.88, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.765494', 'pm2_5': 172.84, 'pm10': 131.65, 'so2': 2.86, 'no2': 341.56, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.776487', 'pm2_5': 246.49, 'pm10': 420.17, 'so2': 280.5, 'no2': 73.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.776487', 'pm2_5': 246.49, 'pm10': 420.17, 'so2': 280.5, 'no2': 73.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.787497', 'pm2_5': 61.47, 'pm10': 434.58, 'so2': 53.03, 'no2': 186.9, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.798503', 'pm2_5': 187.03, 'pm10': 3.73, 'so2': 248.05, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.809490', 'pm2_5': 65.85, 'pm10': 184.79, 'so2': 146.11, 'no2': 235.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.809490', 'pm2_5': 65.85, 'pm10': 184.79, 'so2': 146.11, 'no2': 235.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.820489', 'pm2_5': 21.49, 'pm10': 494.4, 'so2': 79.83, 'no2': 479.37, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.831501', 'pm2_5': 215.94, 'pm10': 226.01, 'so2': 99.33, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.842502', 'pm2_5': 213.28, 'pm10': 223.53, 'so2': 265.12, 'no2': 68.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.842502', 'pm2_5': 213.28, 'pm10': 223.53, 'so2': 265.12, 'no2': 68.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.853502', 'pm2_5': 45.5, 'pm10': 93.44, 'so2': 79.36, 'no2': 338.71, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.864270', 'pm2_5': 9.72, 'pm10': 88.75, 'so2': 117.47, 'no2': 479.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.875261', 'pm2_5': 167.43, 'pm10': 423.81, 'so2': 16.01, 'no2': 403.56, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.875261', 'pm2_5': 167.43, 'pm10': 423.81, 'so2': 16.01, 'no2': 403.56, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.886262', 'pm2_5': 64.39, 'pm10': 184.42, 'so2': 91.35, 'no2': 155.89, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.897259', 'pm2_5': 158.54, 'pm10': 247.44, 'so2': 157.16, 'no2': 130.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.908273', 'pm2_5': 219.9, 'pm10': 20.83, 'so2': 37.4, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.908273', 'pm2_5': 219.9, 'pm10': 20.83, 'so2': 37.4, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.919264', 'pm2_5': 63.41, 'pm10': 225.73, 'so2': 118.78, 'no2': 85.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.930261', 'pm2_5': 100.39, 'pm10': 69.9, 'so2': 221.2, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.941264', 'pm2_5': 217.98, 'pm10': 13.2, 'so2': 88.51, 'no2': 17.68, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.941264', 'pm2_5': 217.98, 'pm10': 13.2, 'so2': 88.51, 'no2': 17.68, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.952276', 'pm2_5': 6.42, 'pm10': 497.68, 'so2': 32.26, 'no2': 17.83, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.963271', 'pm2_5': 120.55, 'pm10': 121.09, 'so2': 40.48, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.974265', 'pm2_5': 4.85, 'pm10': 385.68, 'so2': 57.48, 'no2': 208.92, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.974265', 'pm2_5': 4.85, 'pm10': 385.68, 'so2': 57.48, 'no2': 208.92, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.985267', 'pm2_5': 164.01, 'pm10': 241.4, 'so2': 73.35, 'no2': 110.75, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:18.996272', 'pm2_5': 45.18, 'pm10': 33.56, 'so2': 115.76, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.007272', 'pm2_5': 5.38, 'pm10': 457.85, 'so2': 4.22, 'no2': 261.83, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.007272', 'pm2_5': 5.38, 'pm10': 457.85, 'so2': 4.22, 'no2': 261.83, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.018280', 'pm2_5': 105.77, 'pm10': 467.42, 'so2': 56.56, 'no2': 298.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.029271', 'pm2_5': 65.62, 'pm10': 290.14, 'so2': 236.07, 'no2': 23.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.040282', 'pm2_5': 73.69, 'pm10': 143.12, 'so2': 31.75, 'no2': 155.13, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.040282', 'pm2_5': 73.69, 'pm10': 143.12, 'so2': 31.75, 'no2': 155.13, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.051283', 'pm2_5': 83.02, 'pm10': 239.66, 'so2': 74.22, 'no2': 18.95, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.062275', 'pm2_5': 100.43, 'pm10': 310.89, 'so2': 4.6, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.073287', 'pm2_5': 123.79, 'pm10': 25.85, 'so2': 252.42, 'no2': 441.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.073287', 'pm2_5': 123.79, 'pm10': 25.85, 'so2': 252.42, 'no2': 441.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.084277', 'pm2_5': 217.42, 'pm10': 398.61, 'so2': 129.56, 'no2': 54.28, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.095287', 'pm2_5': 8.11, 'pm10': 158.52, 'so2': 160.15, 'no2': 68.1, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.106286', 'pm2_5': 99.21, 'pm10': 137.88, 'so2': 228.68, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.106286', 'pm2_5': 99.21, 'pm10': 137.88, 'so2': 228.68, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.117288', 'pm2_5': 93.51, 'pm10': 373.56, 'so2': 134.4, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.128289', 'pm2_5': 176.5, 'pm10': 327.55, 'so2': 150.72, 'no2': 51.59, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.139282', 'pm2_5': 111.47, 'pm10': 478.79, 'so2': 196.43, 'no2': 61.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.139282', 'pm2_5': 111.47, 'pm10': 478.79, 'so2': 196.43, 'no2': 61.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.150292', 'pm2_5': 161.51, 'pm10': 299.7, 'so2': 96.84, 'no2': 46.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.161294', 'pm2_5': 167.24, 'pm10': 112.31, 'so2': 23.7, 'no2': 433.58, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.172293', 'pm2_5': 14.66, 'pm10': 11.97, 'so2': 88.14, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.172293', 'pm2_5': 14.66, 'pm10': 11.97, 'so2': 88.14, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.183281', 'pm2_5': 146.18, 'pm10': 128.52, 'so2': 264.94, 'no2': 439.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.194283', 'pm2_5': 169.25, 'pm10': 394.27, 'so2': 297.38, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.205296', 'pm2_5': 38.15, 'pm10': 358.75, 'so2': 241.64, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.205296', 'pm2_5': 38.15, 'pm10': 358.75, 'so2': 241.64, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.216285', 'pm2_5': 92.21, 'pm10': 418.36, 'so2': 153.82, 'no2': 85.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.227297', 'pm2_5': 83.8, 'pm10': 363.71, 'so2': 292.3, 'no2': 232.18, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.238298', 'pm2_5': 242.55, 'pm10': 367.11, 'so2': 148.51, 'no2': 107.8, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.238298', 'pm2_5': 242.55, 'pm10': 367.11, 'so2': 148.51, 'no2': 107.8, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.249296', 'pm2_5': 168.98, 'pm10': 469.81, 'so2': 151.39, 'no2': 137.06, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.260289', 'pm2_5': 147.5, 'pm10': 389.92, 'so2': 50.28, 'no2': 367.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.271302', 'pm2_5': 58.64, 'pm10': 179.91, 'so2': 92.7, 'no2': 309.09, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.271302', 'pm2_5': 58.64, 'pm10': 179.91, 'so2': 92.7, 'no2': 309.09, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.282291', 'pm2_5': 183.39, 'pm10': 213.73, 'so2': 270.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.293290', 'pm2_5': 134.93, 'pm10': 497.23, 'so2': 193.2, 'no2': 233.75, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.304306', 'pm2_5': 71.66, 'pm10': 470.93, 'so2': 263.29, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.304306', 'pm2_5': 71.66, 'pm10': 470.93, 'so2': 263.29, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.315297', 'pm2_5': 18.9, 'pm10': 445.65, 'so2': 149.63, 'no2': 32.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.326296', 'pm2_5': 39.87, 'pm10': 221.96, 'so2': 141.9, 'no2': 161.05, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.337304', 'pm2_5': 200.69, 'pm10': 337.2, 'so2': 62.41, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.337304', 'pm2_5': 200.69, 'pm10': 337.2, 'so2': 62.41, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.348294', 'pm2_5': 54.96, 'pm10': 449.02, 'so2': 121.94, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.359294', 'pm2_5': 243.54, 'pm10': 244.62, 'so2': 11.97, 'no2': 343.23, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.370307', 'pm2_5': 129.13, 'pm10': 366.29, 'so2': 62.08, 'no2': 25.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.370307', 'pm2_5': 129.13, 'pm10': 366.29, 'so2': 62.08, 'no2': 25.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.381299', 'pm2_5': 237.87, 'pm10': 216.4, 'so2': 124.58, 'no2': 83.6, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.392301', 'pm2_5': 169.55, 'pm10': 491.32, 'so2': 281.2, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.403304', 'pm2_5': 110.27, 'pm10': 404.12, 'so2': 174.71, 'no2': 145.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.403304', 'pm2_5': 110.27, 'pm10': 404.12, 'so2': 174.71, 'no2': 145.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.414310', 'pm2_5': 225.63, 'pm10': 80.59, 'so2': 140.41, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.425300', 'pm2_5': 196.71, 'pm10': 443.35, 'so2': 71.1, 'no2': 20.15, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.436458', 'pm2_5': 166.42, 'pm10': 392.3, 'so2': 120.36, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.436458', 'pm2_5': 166.42, 'pm10': 392.3, 'so2': 120.36, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.447314', 'pm2_5': 0.26, 'pm10': 200.29, 'so2': 74.48, 'no2': 436.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.457866', 'pm2_5': 204.27, 'pm10': 32.72, 'so2': 100.41, 'no2': 232.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.468868', 'pm2_5': 57.29, 'pm10': 370.97, 'so2': 210.56, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.468868', 'pm2_5': 57.29, 'pm10': 370.97, 'so2': 210.56, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.479869', 'pm2_5': 249.18, 'pm10': 118.35, 'so2': 235.75, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.490869', 'pm2_5': 65.9, 'pm10': 495.25, 'so2': 1.3, 'no2': 457.86, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.501871', 'pm2_5': 92.97, 'pm10': 32.62, 'so2': 276.5, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.501871', 'pm2_5': 92.97, 'pm10': 32.62, 'so2': 276.5, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.512863', 'pm2_5': 5.09, 'pm10': 437.5, 'so2': 224.93, 'no2': 105.58, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.523862', 'pm2_5': 48.32, 'pm10': 47.26, 'so2': 219.64, 'no2': 65.79, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.534874', 'pm2_5': 112.33, 'pm10': 263.74, 'so2': 290.5, 'no2': 278.1, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.534874', 'pm2_5': 112.33, 'pm10': 263.74, 'so2': 290.5, 'no2': 278.1, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.545864', 'pm2_5': 182.65, 'pm10': 31.95, 'so2': 270.05, 'no2': 450.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.556861', 'pm2_5': 44.05, 'pm10': 70.58, 'so2': 131.56, 'no2': 161.26, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.567864', 'pm2_5': 197.26, 'pm10': 143.62, 'so2': 132.19, 'no2': 154.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.567864', 'pm2_5': 197.26, 'pm10': 143.62, 'so2': 132.19, 'no2': 154.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.578877', 'pm2_5': 109.63, 'pm10': 11.61, 'so2': 127.8, 'no2': 358.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.589864', 'pm2_5': 138.45, 'pm10': 285.58, 'so2': 64.38, 'no2': 6.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.600867', 'pm2_5': 38.63, 'pm10': 186.12, 'so2': 134.71, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.600867', 'pm2_5': 38.63, 'pm10': 186.12, 'so2': 134.71, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.611878', 'pm2_5': 219.57, 'pm10': 170.93, 'so2': 3.14, 'no2': 383.61, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.622877', 'pm2_5': 65.02, 'pm10': 102.87, 'so2': 190.79, 'no2': 290.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.633878', 'pm2_5': 146.04, 'pm10': 470.62, 'so2': 109.18, 'no2': 256.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.633878', 'pm2_5': 146.04, 'pm10': 470.62, 'so2': 109.18, 'no2': 256.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.644879', 'pm2_5': 27.73, 'pm10': 462.0, 'so2': 3.82, 'no2': 138.32, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.655911', 'pm2_5': 49.8, 'pm10': 352.92, 'so2': 5.42, 'no2': 112.73, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.666912', 'pm2_5': 243.34, 'pm10': 225.95, 'so2': 208.75, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.666912', 'pm2_5': 243.34, 'pm10': 225.95, 'so2': 208.75, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.677912', 'pm2_5': 11.22, 'pm10': 324.25, 'so2': 208.89, 'no2': 37.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.688923', 'pm2_5': 54.66, 'pm10': 327.68, 'so2': 75.47, 'no2': 437.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.699916', 'pm2_5': 138.8, 'pm10': 203.79, 'so2': 67.37, 'no2': 407.6, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.699916', 'pm2_5': 138.8, 'pm10': 203.79, 'so2': 67.37, 'no2': 407.6, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.710926', 'pm2_5': 141.63, 'pm10': 92.49, 'so2': 299.58, 'no2': 14.32, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.721917', 'pm2_5': 81.32, 'pm10': 146.79, 'so2': 278.25, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.732916', 'pm2_5': 186.16, 'pm10': 251.6, 'so2': 221.41, 'no2': 305.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.732916', 'pm2_5': 186.16, 'pm10': 251.6, 'so2': 221.41, 'no2': 305.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.744057', 'pm2_5': 136.79, 'pm10': 174.04, 'so2': 276.39, 'no2': 16.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.754928', 'pm2_5': 131.49, 'pm10': 30.99, 'so2': 3.97, 'no2': 462.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.765919', 'pm2_5': 51.32, 'pm10': 86.18, 'so2': 297.22, 'no2': 377.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.765919', 'pm2_5': 51.32, 'pm10': 86.18, 'so2': 297.22, 'no2': 377.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.776930', 'pm2_5': 3.08, 'pm10': 295.4, 'so2': 223.53, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.787930', 'pm2_5': 178.05, 'pm10': 264.24, 'so2': 71.74, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.798934', 'pm2_5': 188.3, 'pm10': 97.19, 'so2': 62.9, 'no2': 423.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.798934', 'pm2_5': 188.3, 'pm10': 97.19, 'so2': 62.9, 'no2': 423.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.809925', 'pm2_5': 40.22, 'pm10': 373.98, 'so2': 15.18, 'no2': 356.21, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.820934', 'pm2_5': 112.69, 'pm10': 377.91, 'so2': 128.96, 'no2': 126.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.831935', 'pm2_5': 172.22, 'pm10': 315.24, 'so2': 59.29, 'no2': 298.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.831935', 'pm2_5': 172.22, 'pm10': 315.24, 'so2': 59.29, 'no2': 298.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.842936', 'pm2_5': 108.27, 'pm10': 133.98, 'so2': 204.68, 'no2': 95.03, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.853937', 'pm2_5': 159.57, 'pm10': 197.03, 'so2': 203.55, 'no2': 458.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.864938', 'pm2_5': 77.18, 'pm10': 206.96, 'so2': 203.77, 'no2': 57.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.864938', 'pm2_5': 77.18, 'pm10': 206.96, 'so2': 203.77, 'no2': 57.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.875929', 'pm2_5': 73.53, 'pm10': 308.84, 'so2': 134.43, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.886927', 'pm2_5': 72.94, 'pm10': 71.12, 'so2': 38.08, 'no2': 390.02, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.897928', 'pm2_5': 236.03, 'pm10': 413.19, 'so2': 236.68, 'no2': 257.72, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.897928', 'pm2_5': 236.03, 'pm10': 413.19, 'so2': 236.68, 'no2': 257.72, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.908933', 'pm2_5': 86.82, 'pm10': 428.81, 'so2': 273.83, 'no2': 491.72, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.919944', 'pm2_5': 177.01, 'pm10': 139.9, 'so2': 279.9, 'no2': 134.88, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.930932', 'pm2_5': 109.77, 'pm10': 2.59, 'so2': 0.55, 'no2': 226.38, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.930932', 'pm2_5': 109.77, 'pm10': 2.59, 'so2': 0.55, 'no2': 226.38, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.941933', 'pm2_5': 245.05, 'pm10': 382.77, 'so2': 30.6, 'no2': 468.4, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.952943', 'pm2_5': 40.07, 'pm10': 64.39, 'so2': 118.5, 'no2': 235.02, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.963944', 'pm2_5': 14.4, 'pm10': 10.92, 'so2': 81.62, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.963944', 'pm2_5': 14.4, 'pm10': 10.92, 'so2': 81.62, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.974944', 'pm2_5': 184.65, 'pm10': 300.53, 'so2': 16.13, 'no2': 156.92, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.985947', 'pm2_5': 245.14, 'pm10': 143.74, 'so2': 279.2, 'no2': 196.55, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.996940', 'pm2_5': 209.76, 'pm10': 434.57, 'so2': 171.75, 'no2': 348.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:19.996940', 'pm2_5': 209.76, 'pm10': 434.57, 'so2': 171.75, 'no2': 348.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.007948', 'pm2_5': 84.68, 'pm10': 226.99, 'so2': 141.17, 'no2': 277.63, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.018939', 'pm2_5': 199.53, 'pm10': 187.21, 'so2': 72.13, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.029942', 'pm2_5': 6.82, 'pm10': 22.32, 'so2': 261.03, 'no2': 486.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.029942', 'pm2_5': 6.82, 'pm10': 22.32, 'so2': 261.03, 'no2': 486.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.040947', 'pm2_5': 30.72, 'pm10': 185.71, 'so2': 278.25, 'no2': 290.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.051950', 'pm2_5': 210.02, 'pm10': 292.44, 'so2': 38.39, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.062949', 'pm2_5': 83.63, 'pm10': 384.48, 'so2': 274.03, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.062949', 'pm2_5': 83.63, 'pm10': 384.48, 'so2': 274.03, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.073950', 'pm2_5': 72.8, 'pm10': 110.79, 'so2': 278.26, 'no2': 215.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.084951', 'pm2_5': 204.31, 'pm10': 309.9, 'so2': 189.11, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.095943', 'pm2_5': 145.65, 'pm10': 16.69, 'so2': 35.18, 'no2': 392.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.095943', 'pm2_5': 145.65, 'pm10': 16.69, 'so2': 35.18, 'no2': 392.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.106944', 'pm2_5': 48.36, 'pm10': 242.08, 'so2': 183.53, 'no2': 142.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.117963', 'pm2_5': 236.61, 'pm10': 124.24, 'so2': 156.84, 'no2': 319.58, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.128945', 'pm2_5': 10.72, 'pm10': 104.66, 'so2': 46.07, 'no2': 233.78, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.128945', 'pm2_5': 10.72, 'pm10': 104.66, 'so2': 46.07, 'no2': 233.78, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.139958', 'pm2_5': 37.7, 'pm10': 109.04, 'so2': 216.81, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.150957', 'pm2_5': 32.31, 'pm10': 231.76, 'so2': 219.89, 'no2': 395.54, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.161951', 'pm2_5': 19.2, 'pm10': 186.97, 'so2': 89.26, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.161951', 'pm2_5': 19.2, 'pm10': 186.97, 'so2': 89.26, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.172950', 'pm2_5': 176.21, 'pm10': 348.19, 'so2': 238.2, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.183951', 'pm2_5': 169.38, 'pm10': 461.16, 'so2': 129.22, 'no2': 332.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.194951', 'pm2_5': 94.86, 'pm10': 20.68, 'so2': 120.17, 'no2': 350.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.194951', 'pm2_5': 94.86, 'pm10': 20.68, 'so2': 120.17, 'no2': 350.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.205952', 'pm2_5': 72.71, 'pm10': 320.05, 'so2': 231.88, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.216963', 'pm2_5': 154.49, 'pm10': 34.44, 'so2': 268.43, 'no2': 443.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.227955', 'pm2_5': 39.99, 'pm10': 305.42, 'so2': 270.23, 'no2': 469.78, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.227955', 'pm2_5': 39.99, 'pm10': 305.42, 'so2': 270.23, 'no2': 469.78, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.238963', 'pm2_5': 84.7, 'pm10': 187.21, 'so2': 208.66, 'no2': 452.29, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.249955', 'pm2_5': 172.21, 'pm10': 259.43, 'so2': 36.81, 'no2': 413.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.260954', 'pm2_5': 91.73, 'pm10': 487.96, 'so2': 24.26, 'no2': 310.73, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.260954', 'pm2_5': 91.73, 'pm10': 487.96, 'so2': 24.26, 'no2': 310.73, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.271958', 'pm2_5': 66.6, 'pm10': 374.99, 'so2': 141.63, 'no2': 264.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.282969', 'pm2_5': 134.09, 'pm10': 349.38, 'so2': 299.24, 'no2': 347.15, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.293969', 'pm2_5': 249.42, 'pm10': 446.65, 'so2': 271.81, 'no2': 125.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.293969', 'pm2_5': 249.42, 'pm10': 446.65, 'so2': 271.81, 'no2': 125.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.304969', 'pm2_5': 38.66, 'pm10': 170.08, 'so2': 286.08, 'no2': 91.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.315960', 'pm2_5': 236.18, 'pm10': 315.22, 'so2': 156.48, 'no2': 76.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.326971', 'pm2_5': 26.23, 'pm10': 376.54, 'so2': 72.67, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.326971', 'pm2_5': 26.23, 'pm10': 376.54, 'so2': 72.67, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.337971', 'pm2_5': 52.29, 'pm10': 21.15, 'so2': 296.01, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.348975', 'pm2_5': 116.35, 'pm10': 264.19, 'so2': 27.65, 'no2': 479.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.359975', 'pm2_5': 33.75, 'pm10': 153.36, 'so2': 5.02, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.359975', 'pm2_5': 33.75, 'pm10': 153.36, 'so2': 5.02, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.370974', 'pm2_5': 108.71, 'pm10': 293.72, 'so2': 298.07, 'no2': 50.85, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.381966', 'pm2_5': 54.51, 'pm10': 302.76, 'so2': 120.66, 'no2': 180.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.392967', 'pm2_5': 87.92, 'pm10': 280.73, 'so2': 213.08, 'no2': 164.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.392967', 'pm2_5': 87.92, 'pm10': 280.73, 'so2': 213.08, 'no2': 164.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.403972', 'pm2_5': 103.1, 'pm10': 41.28, 'so2': 126.92, 'no2': 217.37, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.414977', 'pm2_5': 243.83, 'pm10': 152.23, 'so2': 0.29, 'no2': 400.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.425970', 'pm2_5': 197.9, 'pm10': 417.57, 'so2': 99.04, 'no2': 441.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.425970', 'pm2_5': 197.9, 'pm10': 417.57, 'so2': 99.04, 'no2': 441.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.436981', 'pm2_5': 87.75, 'pm10': 226.76, 'so2': 269.76, 'no2': 294.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.447974', 'pm2_5': 222.9, 'pm10': 235.54, 'so2': 9.12, 'no2': 432.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.458977', 'pm2_5': 19.08, 'pm10': 80.15, 'so2': 121.63, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.458977', 'pm2_5': 19.08, 'pm10': 80.15, 'so2': 121.63, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.469982', 'pm2_5': 31.76, 'pm10': 458.43, 'so2': 255.3, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.480986', 'pm2_5': 46.48, 'pm10': 321.98, 'so2': 201.37, 'no2': 328.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.491984', 'pm2_5': 75.92, 'pm10': 217.68, 'so2': 28.68, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.491984', 'pm2_5': 75.92, 'pm10': 217.68, 'so2': 28.68, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.502985', 'pm2_5': 22.88, 'pm10': 191.14, 'so2': 132.27, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.513985', 'pm2_5': 83.24, 'pm10': 308.51, 'so2': 198.69, 'no2': 443.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:20.524986', 'pm2_5': 231.54, 'pm10': 498.96, 'so2': 252.3, 'no2': 195.56, 'health_environment': 'unhealthy'}
# ...
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.655445', 'pm2_5': 244.45, 'pm10': 327.42, 'so2': 104.34, 'no2': 326.23, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.665999', 'pm2_5': 145.37, 'pm10': 147.41, 'so2': 293.77, 'no2': 331.43, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.677009', 'pm2_5': 174.52, 'pm10': 471.56, 'so2': 43.0, 'no2': 487.19, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.677009', 'pm2_5': 174.52, 'pm10': 471.56, 'so2': 43.0, 'no2': 487.19, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.687996', 'pm2_5': 75.79, 'pm10': 306.03, 'so2': 261.71, 'no2': 207.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.699009', 'pm2_5': 218.28, 'pm10': 280.95, 'so2': 212.47, 'no2': 212.23, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.709997', 'pm2_5': 229.28, 'pm10': 310.43, 'so2': 23.86, 'no2': 104.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.709997', 'pm2_5': 229.28, 'pm10': 310.43, 'so2': 23.86, 'no2': 104.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.720999', 'pm2_5': 34.69, 'pm10': 14.74, 'so2': 168.49, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.732003', 'pm2_5': 102.26, 'pm10': 377.47, 'so2': 68.84, 'no2': 255.17, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.743004', 'pm2_5': 81.47, 'pm10': 486.63, 'so2': 25.25, 'no2': 67.22, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.743004', 'pm2_5': 81.47, 'pm10': 486.63, 'so2': 25.25, 'no2': 67.22, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.754015', 'pm2_5': 194.3, 'pm10': 103.49, 'so2': 261.21, 'no2': 470.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.765004', 'pm2_5': 49.76, 'pm10': 112.21, 'so2': 63.94, 'no2': 280.49, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.776015', 'pm2_5': 71.93, 'pm10': 67.68, 'so2': 61.89, 'no2': 329.91, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.776015', 'pm2_5': 71.93, 'pm10': 67.68, 'so2': 61.89, 'no2': 329.91, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.787015', 'pm2_5': 49.09, 'pm10': 346.23, 'so2': 53.88, 'no2': 40.94, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.798007', 'pm2_5': 92.71, 'pm10': 377.09, 'so2': 29.51, 'no2': 242.14, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.809017', 'pm2_5': 5.17, 'pm10': 218.47, 'so2': 144.88, 'no2': 226.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.809017', 'pm2_5': 5.17, 'pm10': 218.47, 'so2': 144.88, 'no2': 226.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.820019', 'pm2_5': 70.98, 'pm10': 455.08, 'so2': 223.08, 'no2': 469.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.831173', 'pm2_5': 195.7, 'pm10': 377.74, 'so2': 213.81, 'no2': 483.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.842021', 'pm2_5': 48.79, 'pm10': 210.88, 'so2': 212.38, 'no2': 377.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.842021', 'pm2_5': 48.79, 'pm10': 210.88, 'so2': 212.38, 'no2': 377.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.853023', 'pm2_5': 5.89, 'pm10': 154.96, 'so2': 235.54, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.864018', 'pm2_5': 17.92, 'pm10': 156.22, 'so2': 147.4, 'no2': 110.54, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.875024', 'pm2_5': 119.52, 'pm10': 444.87, 'so2': 245.39, 'no2': 137.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.875024', 'pm2_5': 119.52, 'pm10': 444.87, 'so2': 245.39, 'no2': 137.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.886014', 'pm2_5': 198.9, 'pm10': 2.83, 'so2': 106.63, 'no2': 396.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.897012', 'pm2_5': 24.76, 'pm10': 342.64, 'so2': 121.01, 'no2': 155.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.908028', 'pm2_5': 89.92, 'pm10': 82.38, 'so2': 281.02, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.908028', 'pm2_5': 89.92, 'pm10': 82.38, 'so2': 281.02, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.919028', 'pm2_5': 35.43, 'pm10': 442.42, 'so2': 249.1, 'no2': 359.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.930014', 'pm2_5': 243.3, 'pm10': 168.94, 'so2': 94.07, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.941018', 'pm2_5': 65.28, 'pm10': 46.68, 'so2': 34.33, 'no2': 188.71, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.941018', 'pm2_5': 65.28, 'pm10': 46.68, 'so2': 34.33, 'no2': 188.71, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.952033', 'pm2_5': 172.35, 'pm10': 423.98, 'so2': 239.33, 'no2': 475.26, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.963020', 'pm2_5': 105.9, 'pm10': 157.42, 'so2': 163.88, 'no2': 439.94, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.974029', 'pm2_5': 22.83, 'pm10': 125.59, 'so2': 265.42, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.974029', 'pm2_5': 22.83, 'pm10': 125.59, 'so2': 265.42, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.985019', 'pm2_5': 23.29, 'pm10': 287.54, 'so2': 284.88, 'no2': 477.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:22.996020', 'pm2_5': 171.76, 'pm10': 124.25, 'so2': 134.37, 'no2': 396.95, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.007022', 'pm2_5': 13.15, 'pm10': 185.18, 'so2': 113.04, 'no2': 182.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.007022', 'pm2_5': 13.15, 'pm10': 185.18, 'so2': 113.04, 'no2': 182.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.018019', 'pm2_5': 184.83, 'pm10': 398.07, 'so2': 214.38, 'no2': 284.13, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.029021', 'pm2_5': 93.49, 'pm10': 462.34, 'so2': 36.12, 'no2': 107.87, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.040024', 'pm2_5': 12.77, 'pm10': 102.47, 'so2': 16.03, 'no2': 406.22, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.040024', 'pm2_5': 12.77, 'pm10': 102.47, 'so2': 16.03, 'no2': 406.22, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.051024', 'pm2_5': 59.61, 'pm10': 426.12, 'so2': 46.4, 'no2': 50.98, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.062023', 'pm2_5': 105.46, 'pm10': 117.92, 'so2': 272.49, 'no2': 139.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.073036', 'pm2_5': 186.15, 'pm10': 215.2, 'so2': 293.83, 'no2': 494.79, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.073036', 'pm2_5': 186.15, 'pm10': 215.2, 'so2': 293.83, 'no2': 494.79, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.084037', 'pm2_5': 102.54, 'pm10': 353.83, 'so2': 240.86, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.095037', 'pm2_5': 70.18, 'pm10': 464.39, 'so2': 263.13, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.106027', 'pm2_5': 79.66, 'pm10': 248.53, 'so2': 182.75, 'no2': 358.35, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.106027', 'pm2_5': 79.66, 'pm10': 248.53, 'so2': 182.75, 'no2': 358.35, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.117027', 'pm2_5': 145.82, 'pm10': 485.64, 'so2': 199.45, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.128036', 'pm2_5': 209.88, 'pm10': 428.2, 'so2': 197.66, 'no2': 103.81, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.139040', 'pm2_5': 235.36, 'pm10': 294.35, 'so2': 107.56, 'no2': 248.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.139040', 'pm2_5': 235.36, 'pm10': 294.35, 'so2': 107.56, 'no2': 248.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.150033', 'pm2_5': 228.33, 'pm10': 256.05, 'so2': 221.0, 'no2': 394.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.161030', 'pm2_5': 68.01, 'pm10': 430.0, 'so2': 92.7, 'no2': 249.6, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.172045', 'pm2_5': 165.98, 'pm10': 359.93, 'so2': 277.77, 'no2': 176.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.172045', 'pm2_5': 165.98, 'pm10': 359.93, 'so2': 277.77, 'no2': 176.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.183035', 'pm2_5': 212.59, 'pm10': 52.22, 'so2': 139.09, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.194047', 'pm2_5': 174.08, 'pm10': 267.05, 'so2': 286.0, 'no2': 104.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.205047', 'pm2_5': 144.85, 'pm10': 213.2, 'so2': 8.16, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.205047', 'pm2_5': 144.85, 'pm10': 213.2, 'so2': 8.16, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.216037', 'pm2_5': 230.09, 'pm10': 252.57, 'so2': 135.52, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.227049', 'pm2_5': 165.08, 'pm10': 172.79, 'so2': 287.59, 'no2': 280.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.238050', 'pm2_5': 125.32, 'pm10': 370.9, 'so2': 10.61, 'no2': 246.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.238050', 'pm2_5': 125.32, 'pm10': 370.9, 'so2': 10.61, 'no2': 246.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.249048', 'pm2_5': 74.11, 'pm10': 162.33, 'so2': 180.56, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.260053', 'pm2_5': 179.05, 'pm10': 401.94, 'so2': 154.82, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.271053', 'pm2_5': 242.36, 'pm10': 399.8, 'so2': 202.38, 'no2': 270.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.271053', 'pm2_5': 242.36, 'pm10': 399.8, 'so2': 202.38, 'no2': 270.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.282042', 'pm2_5': 52.45, 'pm10': 347.66, 'so2': 5.56, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.293041', 'pm2_5': 108.55, 'pm10': 169.74, 'so2': 129.83, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.304054', 'pm2_5': 179.48, 'pm10': 445.58, 'so2': 268.47, 'no2': 358.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.304054', 'pm2_5': 179.48, 'pm10': 445.58, 'so2': 268.47, 'no2': 358.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.315043', 'pm2_5': 85.87, 'pm10': 479.27, 'so2': 253.27, 'no2': 28.53, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.326043', 'pm2_5': 139.08, 'pm10': 289.26, 'so2': 202.8, 'no2': 97.02, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.337045', 'pm2_5': 205.99, 'pm10': 281.3, 'so2': 95.05, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.337045', 'pm2_5': 205.99, 'pm10': 281.3, 'so2': 95.05, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.348059', 'pm2_5': 183.37, 'pm10': 242.39, 'so2': 82.48, 'no2': 228.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.359058', 'pm2_5': 131.44, 'pm10': 367.24, 'so2': 155.4, 'no2': 334.79, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.370059', 'pm2_5': 241.06, 'pm10': 128.19, 'so2': 47.79, 'no2': 322.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.370059', 'pm2_5': 241.06, 'pm10': 128.19, 'so2': 47.79, 'no2': 322.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.381051', 'pm2_5': 44.25, 'pm10': 63.41, 'so2': 71.02, 'no2': 107.67, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.392063', 'pm2_5': 93.16, 'pm10': 20.28, 'so2': 226.62, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.403055', 'pm2_5': 41.31, 'pm10': 297.13, 'so2': 47.06, 'no2': 121.46, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.403055', 'pm2_5': 41.31, 'pm10': 297.13, 'so2': 47.06, 'no2': 121.46, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.414051', 'pm2_5': 70.71, 'pm10': 348.98, 'so2': 270.9, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.425064', 'pm2_5': 161.66, 'pm10': 350.52, 'so2': 183.25, 'no2': 255.47, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.436064', 'pm2_5': 238.64, 'pm10': 194.06, 'so2': 207.71, 'no2': 443.35, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.436064', 'pm2_5': 238.64, 'pm10': 194.06, 'so2': 207.71, 'no2': 443.35, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.447064', 'pm2_5': 230.88, 'pm10': 72.03, 'so2': 104.68, 'no2': 215.93, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.458064', 'pm2_5': 208.59, 'pm10': 16.31, 'so2': 71.14, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.469065', 'pm2_5': 58.49, 'pm10': 81.48, 'so2': 69.79, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.469065', 'pm2_5': 58.49, 'pm10': 81.48, 'so2': 69.79, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-03-31T15:58:23.480060', 'pm2_5': 38.99, 'pm10': 94.61, 'so2': 117.79, 'no2': 205.25, 'health_environment': 'unhealthy'}
# Saved Air Quality XML: sensor_data/xml\air_quality_readings_errors.xml
# Saved Air Quality XML: sensor_data/xml\air_quality_readings.xml
